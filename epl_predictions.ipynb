# %% [markdown]
# # Making Predictions on Soccer Matches in the English Premier League using Machine Learning

# %% [markdown]
# Import the Python libraries `pandas`, `requests`, `BeautifulSoup`, and `sklearn`

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import sklearn

# %% [markdown]
# Initialize the variables

# %%
matches = pd.read_csv("all_matches_1992_2022.csv", index_col=0)

# %%
# Find columns in DataFrame that are numeric, which can be used as predictors
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
# Convert `date` column to numeric using `pandas`
matches["date"] = pd.to_datetime(matches["date"])

matches["date"].dtype.name
# Out:
# 'datetime64[ns]'

# %%
# Convert `venue` column to numeric value to create predictor for home-field advantage
matches["venue_code"] = matches["venue"].astype("category")

# Assign a numeric value to each category
matches["venue_code"] = matches["venue_code"].cat.codes

matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2 2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3 2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  notes    sh  sot  dist   fk   pk pkatt season  \
# 0  Crystal Palace  ...    NaN  10.0  2.0  14.6  1.0  0.0   0.0   2022
# 1  Leicester City  ...    NaN  19.0  7.0  13.0  0.0  0.0   0.0   2022
# 2     Bournemouth  ...    NaN  14.0  6.0  14.8  0.0  0.0   0.0   2022
# 3          Fulham  ...    NaN  22.0  8.0  15.5  1.0  0.0   0.0   2022
# 4     Aston Villa  ...    NaN  22.0  8.0  16.3  1.0  0.0   0.0   2022
#
#       team  venue_code
# 0  Arsenal           0
# 1  Arsenal           1
# 2  Arsenal           0
# 3  Arsenal           1
# 4  Arsenal           1
#
# [5 rows x 28 columns]

# %%
# For each team, repeat the steps above to assign a numeric value for each opponent
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2 2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3 2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...    sh  sot  dist   fk   pk pkatt season     team  \
# 0  Crystal Palace  ...  10.0  2.0  14.6  1.0  0.0   0.0   2022  Arsenal
# 1  Leicester City  ...  19.0  7.0  13.0  0.0  0.0   0.0   2022  Arsenal
# 2     Bournemouth  ...  14.0  6.0  14.8  0.0  0.0   0.0   2022  Arsenal
# 3          Fulham  ...  22.0  8.0  15.5  1.0  0.0   0.0   2022  Arsenal
# 4     Aston Villa  ...  22.0  8.0  16.3  1.0  0.0   0.0   2022  Arsenal
#
#    venue_code  opp_code
# 0           0         8
# 1           1        13
# 2           0         2
# 3           1        10
# 4           1         1
#
# [5 rows x 29 columns]

# %%
# Extract only the hour value from the `time` column in order to determine results of matches at different hours of the day
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2 2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3 2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  sot  dist   fk   pk pkatt season     team venue_code  \
# 0  Crystal Palace  ...  2.0  14.6  1.0  0.0   0.0   2022  Arsenal          0
# 1  Leicester City  ...  7.0  13.0  0.0  0.0   0.0   2022  Arsenal          1
# 2     Bournemouth  ...  6.0  14.8  0.0  0.0   0.0   2022  Arsenal          0
# 3          Fulham  ...  8.0  15.5  1.0  0.0   0.0   2022  Arsenal          1
# 4     Aston Villa  ...  8.0  16.3  1.0  0.0   0.0   2022  Arsenal          1
#
#    opp_code  hour
# 0         8    20
# 1        13    15
# 2         2    17
# 3        10    17
# 4         1    19
#
# [5 rows x 30 columns]

# %%
# Assign a numeric value for each day of the week to determine results of matches at different days
matches["day_code"] = matches["date"].dt.dayofweek

matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 0 2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W  2.0  0.0
# 1 2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  2.0
# 2 2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  0.0
# 3 2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home      W  2.0  1.0
# 4 2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  2.0  1.0
#
#          opponent  ...  dist   fk   pk  pkatt season     team venue_code  \
# 0  Crystal Palace  ...  14.6  1.0  0.0    0.0   2022  Arsenal          0
# 1  Leicester City  ...  13.0  0.0  0.0    0.0   2022  Arsenal          1
# 2     Bournemouth  ...  14.8  0.0  0.0    0.0   2022  Arsenal          0
# 3          Fulham  ...  15.5  1.0  0.0    0.0   2022  Arsenal          1
# 4     Aston Villa  ...  16.3  1.0  0.0    0.0   2022  Arsenal          1
#
#   opp_code  hour  day_code
# 0        8    20         4
# 1       13    15         5
# 2        2    17         5
# 3       10    17         5
# 4        1    19         2
#
# [5 rows x 31 columns]

# %%
# Assign a numeric value for the result (win/draw/loss)
matches["result_targets"] = matches["result"].astype("category").cat.codes

matches.head(20)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2022-08-05  20:00  Premier League   Matchweek 1  Fri  Away      W  2.0
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 2  2022-08-20  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 3  2022-08-27  17:30  Premier League   Matchweek 4  Sat  Home      W  2.0
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  2.0
# 5  2022-09-04  16:30  Premier League   Matchweek 6  Sun  Away      L  1.0
# 7  2022-09-18  12:00  Premier League   Matchweek 8  Sun  Away      W  3.0
# 8  2022-10-01  12:30  Premier League   Matchweek 9  Sat  Home      W  3.0
# 10 2022-10-09  16:30  Premier League  Matchweek 10  Sun  Home      W  3.0
# 12 2022-10-16  14:00  Premier League  Matchweek 11  Sun  Away      W  1.0
# 14 2022-10-23  14:00  Premier League  Matchweek 13  Sun  Away      D  1.0
# 16 2022-10-30  14:00  Premier League  Matchweek 14  Sun  Home      W  5.0
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D  3.0
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# 6  2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W  3.0
# 10 2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      W  6.0
#
#      ga         opponent  ...   fk   pk  pkatt  season             team  \
# 0   0.0   Crystal Palace  ...  1.0  0.0    0.0    2022          Arsenal
# 1   2.0   Leicester City  ...  0.0  0.0    0.0    2022          Arsenal
# 2   0.0      Bournemouth  ...  0.0  0.0    0.0    2022          Arsenal
# 3   1.0           Fulham  ...  1.0  0.0    0.0    2022          Arsenal
# 4   1.0      Aston Villa  ...  1.0  0.0    0.0    2022          Arsenal
# 5   3.0   Manchester Utd  ...  1.0  0.0    0.0    2022          Arsenal
# 7   0.0        Brentford  ...  0.0  0.0    0.0    2022          Arsenal
# 8   1.0        Tottenham  ...  1.0  0.0    0.0    2022          Arsenal
# 10  2.0        Liverpool  ...  0.0  1.0    1.0    2022          Arsenal
# 12  0.0     Leeds United  ...  1.0  0.0    0.0    2022          Arsenal
# 14  1.0      Southampton  ...  0.0  0.0    0.0    2022          Arsenal
# 16  0.0  Nott'ham Forest  ...  1.0  0.0    0.0    2022          Arsenal
# 1   0.0         West Ham  ...  1.0  1.0    1.0    2022  Manchester City
# 2   0.0      Bournemouth  ...  0.0  0.0    0.0    2022  Manchester City
# 3   3.0    Newcastle Utd  ...  1.0  0.0    0.0    2022  Manchester City
# 4   2.0   Crystal Palace  ...  0.0  0.0    0.0    2022  Manchester City
# 5   0.0  Nott'ham Forest  ...  0.0  0.0    0.0    2022  Manchester City
# 6   1.0      Aston Villa  ...  1.0  0.0    0.0    2022  Manchester City
# 9   0.0           Wolves  ...  0.0  0.0    0.0    2022  Manchester City
# 10  3.0   Manchester Utd  ...  1.0  0.0    0.0    2022  Manchester City
#
#    venue_code opp_code hour  day_code  result_targets
# 0           0        8   20         4               2
# 1           1       13   15         5               2
# 2           0        2   17         5               2
# 3           1       10   17         5               2
# 4           1        1   19         2               2
# 5           0       16   16         6               1
# 7           0        3   12         6               2
# 8           1       24   12         5               2
# 10          1       14   16         6               2
# 12          0       12   14         6               2
# 14          0       21   14         6               0
# 16          1       19   14         6               2
# 1           0       27   16         6               2
# 2           1        2   15         5               2
# 3           0       17   16         6               0
# 4           1        8   15         5               2
# 5           1       19   19         2               2
# 6           0        1   17         5               0
# 9           0       28   12         5               2
# 10          1       16   14         6               2
#
# [20 rows x 32 columns]

# %% [markdown]
# From `sklearn`, import a random forest classifier to make the initial predictions

# %%
from sklearn.ensemble import RandomForestClassifier as rfc

# %%
rf = rfc(n_estimators=50, min_samples_split=10, random_state=1)

# %% [markdown]
# Split the dataset into training and test data. The model will be trained on the training data, and predictions will be made on the test data.
# For this, the training data will be all seasons preceding 2022 (current season), and the test data will be 2022 (current season)

# %%
train = matches[matches["date"] < '2022-01-01']
test = matches[matches["date"] >= '2022-01-01']

# %%
# Create a list of the predictors
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %% [markdown]
# Build a forest of trees from the training data using the `RandomForestClassifier.fit()` method. [Link](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier.fit)

# %%
rf.fit(train[predictors], train["result_targets"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %% [markdown]
# Generate predictions using the `RandomForestClassifier.predict()` method. [Link](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier.predict)

# %%
predictions = rf.predict(test[predictors])

# %% [markdown]
# Measure the precision of the predictions, using `accuracy_score`. [Link](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# Use `accuracy_score` to determine the accuracy of the model.

# %%
accuracy = accuracy_score(test["result_targets"], predictions)

# %%
accuracy
# Out:
# 0.4504643962848297

# %% [markdown]
# With the accuracy not being great, I will explore the dataset to see which data points were more/less accurate.

# %% [markdown]
# Create a new dataframe combining the test data and predictions

# %%
combined = pd.DataFrame(dict(actual=test["result_targets"], prediction=predictions))

# %%
# Use `pandas.crosstab()` method to create a table of predicted vs actual outcomes
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0    1    2
# actual
# 0           15   63   66
# 1           30  133   88
# 2           23   85  143

# %% [markdown]
# The resulting table states that the model was more accurate when predicting wins/losses, but inaccurate when predicting draws

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["result_targets"], predictions, average=None)
# Out:
# array([0.22058824, 0.47330961, 0.48148148])

# %% [markdown]
# Looking from the `precision_score` above, the percentage of correct predictions are stated for draws, losses, wins respectively.

# %% [markdown]
# The model can be improved by computing rolling averages based off of the average team stats in the last N matches. These averages can give the model information about previous matches in order to make a better prediction.

# %% [markdown]
# Create a dataframe for the teams

# %%
grouped_matches = matches.groupby("team")

# %% [markdown]
# Define the `rolling_averages` function to take in a group, existing columns, and new columns

# %%
def rolling_averages(group, columns, new_columns):
    group = group.sort_values("date")
    
    # Take the set of columns and compute the rolling average for the previous 3 iterations.
    # closed='left' indicates that the current week will not be included
    rolling_stats = group[columns].rolling(3, closed='left').mean()
    
    group[new_columns] = rolling_stats
    
    # If data is not available (ex. 3 weeks of data not available for Week 2), remove the missing values from group
    group = group.dropna(subset=new_columns)
    
    return group

# %% [markdown]
# Define columns that will be informative for calculating rolling averages (numeric) and create new columns to hold value of rolling average for each of these columns.

# %%
columns = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_columns = [f"{column}_rolling" for column in columns]

# %% [markdown]
# For each team, apply the `rolling_averages` function for the columns defined

# %%
matches_rolling = matches.groupby("team").apply(lambda group: rolling_averages(group, columns, new_columns))

# %%
# Remove the left-most index of team-name that was added on from previous step
matches_rolling = matches_rolling.droplevel("team")

# Assign unique index numbers for each match
matches_rolling.index = range(matches_rolling.shape[0])

matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2017-09-09  15:00  Premier League   Matchweek 4  Sat  Home      W  3.0
# 1    2017-09-17  13:30  Premier League   Matchweek 5  Sun  Away      D  0.0
# 2    2017-09-25  20:00  Premier League   Matchweek 6  Mon  Home      W  2.0
# 3    2017-10-01  12:00  Premier League   Matchweek 7  Sun  Home      W  2.0
# 4    2017-10-14  17:30  Premier League   Matchweek 8  Sat  Away      L  1.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 3951 2022-10-08  15:00  Premier League  Matchweek 10  Sat  Away      L  0.0
# 3952 2022-10-15  15:00  Premier League  Matchweek 11  Sat  Home      W  1.0
# 3953 2022-10-18  20:15  Premier League  Matchweek 12  Tue  Away      L  1.0
# 3954 2022-10-23  14:00  Premier League  Matchweek 13  Sun  Home      L  0.0
# 3955 2022-10-29  15:00  Premier League  Matchweek 14  Sat  Away      D  1.0
#
#        ga         opponent  ...  day_code  result_targets  gf_rolling  \
# 0     0.0      Bournemouth  ...         5               2    1.333333
# 1     0.0          Chelsea  ...         6               0    1.000000
# 2     0.0        West Brom  ...         0               2    1.000000
# 3     0.0         Brighton  ...         6               2    1.666667
# 4     2.0          Watford  ...         5               1    1.333333
# ...   ...              ...  ...       ...             ...         ...
# 3951  3.0          Chelsea  ...         5               1    0.333333
# 3952  0.0  Nott'ham Forest  ...         5               2    0.000000
# 3953  2.0   Crystal Palace  ...         1               1    0.333333
# 3954  4.0   Leicester City  ...         6               1    0.666667
# 3955  1.0        Brentford  ...         5               0    0.666667
#
#       ga_rolling sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  \
# 0       2.666667  17.666667    5.333333    18.133333   0.000000    0.000000
# 1       1.666667  14.333333    5.000000    16.766667   0.333333    0.000000
# 2       1.333333  12.000000    3.666667    16.566667   0.333333    0.000000
# 3       0.000000  14.333333    5.333333    17.400000   1.333333    0.333333
# 4       0.000000  17.000000    5.000000    18.333333   1.666667    0.333333
# ...          ...        ...         ...          ...        ...         ...
# 3951    1.666667   9.333333    2.333333    18.033333   0.666667    0.000000
# 3952    2.666667   9.666667    2.333333    18.600000   1.000000    0.000000
# 3953    1.666667  10.333333    2.333333    17.933333   0.333333    0.333333
# 3954    1.666667   8.666667    2.333333    16.366667   0.666667    0.333333
# 3955    2.000000  13.000000    3.333333    16.766667   0.666667    0.333333
#
#       pkatt_rolling
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.333333
# 4          0.333333
# ...             ...
# 3951       0.000000
# 3952       0.000000
# 3953       0.333333
# 3954       0.333333
# 3955       0.333333
#
# [3956 rows x 40 columns]

# %% [markdown]
# With these new predictors, the model can be re-trained to hopefully provide more accurate predictions.

# %%
# Define a function that will split the dataset into training and test sets, make predictions, and return predictions

def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] >= '2022-01-01']
    
    rf.fit(train[predictors], train["result_targets"])
    
    predictions = rf.predict(test[predictors])
    
    combined = pd.DataFrame(dict(actual=test["result_targets"], predicted=predictions), index=test.index)
    precision = precision_score(test["result_targets"], predictions, average=None)
    
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_columns)

# %% [markdown]
# The precision of the model with the new rolling_averages predictors increased, but only slightly.

# %%
precision
# Out:
# array([0.22222222, 0.52411576, 0.49508197])

# %%
# Add the date, team, opponent, and results into the `combined` dataframe
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 168        1          2 2022-01-01                  Arsenal  Manchester City
# 169        0          2 2022-01-23                  Arsenal          Burnley
# 170        2          2 2022-02-10                  Arsenal           Wolves
# 171        2          2 2022-02-19                  Arsenal        Brentford
# 172        2          2 2022-02-24                  Arsenal           Wolves
# ...      ...        ...        ...                      ...              ...
# 3951       1          1 2022-10-08  Wolverhampton Wanderers          Chelsea
# 3952       2          2 2022-10-15  Wolverhampton Wanderers  Nott'ham Forest
# 3953       1          1 2022-10-18  Wolverhampton Wanderers   Crystal Palace
# 3954       1          1 2022-10-23  Wolverhampton Wanderers   Leicester City
# 3955       0          1 2022-10-29  Wolverhampton Wanderers        Brentford
#
#      result
# 168       L
# 169       D
# 170       W
# 171       W
# 172       W
# ...     ...
# 3951      L
# 3952      W
# 3953      L
# 3954      L
# 3955      D
#
# [643 rows x 6 columns]

# %% [markdown]
# To fix the issue of having the model predict that both teams may win, there needs to be a filter for predictions where the model believes there will be 1 winner and 1 loser.

# %%
# The names in the opponent column differ slightly, so this dictionary matches the name from 'team' with 'opponent' where it differs

class MissingDict(dict):
    # If key does not exist in dictionary, then assign key as given value
    __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion": "Brighton", 
    "Manchester United": "Manchester Utd", 
    "Newcastle United": "Newcastle Utd", 
    "Tottenham Hotspur": "Tottenham", 
    "West Ham United": "West Ham", 
    "Wolverhampton Wanderers": "Wolves"
}

mapping = MissingDict(**map_values)

# %%
mapping["Tottenham Hotspur"]
# Out:
# 'Tottenham'

# %%
mapping["Manchester City"]
# Out:
# 'Manchester City'

# %% [markdown]
# Rename the team names in the 'team' column to align with the names in the 'opponent' column

# %%
combined["new_team_name"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 168        1          2 2022-01-01                  Arsenal  Manchester City
# 169        0          2 2022-01-23                  Arsenal          Burnley
# 170        2          2 2022-02-10                  Arsenal           Wolves
# 171        2          2 2022-02-19                  Arsenal        Brentford
# 172        2          2 2022-02-24                  Arsenal           Wolves
# ...      ...        ...        ...                      ...              ...
# 3951       1          1 2022-10-08  Wolverhampton Wanderers          Chelsea
# 3952       2          2 2022-10-15  Wolverhampton Wanderers  Nott'ham Forest
# 3953       1          1 2022-10-18  Wolverhampton Wanderers   Crystal Palace
# 3954       1          1 2022-10-23  Wolverhampton Wanderers   Leicester City
# 3955       0          1 2022-10-29  Wolverhampton Wanderers        Brentford
#
#      result new_team_name
# 168       L       Arsenal
# 169       D       Arsenal
# 170       W       Arsenal
# 171       W       Arsenal
# 172       W       Arsenal
# ...     ...           ...
# 3951      L        Wolves
# 3952      W        Wolves
# 3953      L        Wolves
# 3954      L        Wolves
# 3955      D        Wolves
#
# [643 rows x 7 columns]

# %% [markdown]
# Merge the dataframe onto itself, aligning `new_team_name` with `opponent` while matching `date` to merge a single match on each side.

# %%
merge = combined.merge(combined, left_on=["date", "new_team_name"], right_on=["date", "opponent"])

# %%
merge
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           1            2 2022-01-01                  Arsenal
# 1           0            2 2022-01-23                  Arsenal
# 2           2            2 2022-02-10                  Arsenal
# 3           2            2 2022-02-19                  Arsenal
# 4           2            2 2022-02-24                  Arsenal
# ..        ...          ...        ...                      ...
# 625         1            1 2022-10-08  Wolverhampton Wanderers
# 626         2            2 2022-10-15  Wolverhampton Wanderers
# 627         1            1 2022-10-18  Wolverhampton Wanderers
# 628         1            1 2022-10-23  Wolverhampton Wanderers
# 629         0            1 2022-10-29  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_name_x  actual_y  predicted_y  \
# 0    Manchester City        L         Arsenal         2            2
# 1            Burnley        D         Arsenal         0            1
# 2             Wolves        W         Arsenal         1            1
# 3          Brentford        W         Arsenal         1            1
# 4             Wolves        W         Arsenal         1            1
# ..               ...      ...             ...       ...          ...
# 625          Chelsea        L          Wolves         2            0
# 626  Nott'ham Forest        W          Wolves         1            1
# 627   Crystal Palace        L          Wolves         2            0
# 628   Leicester City        L          Wolves         2            1
# 629        Brentford        D          Wolves         0            2
#
#                       team_y opponent_y result_y    new_team_name_y
# 0            Manchester City    Arsenal        W    Manchester City
# 1                    Burnley    Arsenal        D            Burnley
# 2    Wolverhampton Wanderers    Arsenal        L             Wolves
# 3                  Brentford    Arsenal        L          Brentford
# 4    Wolverhampton Wanderers    Arsenal        L             Wolves
# ..                       ...        ...      ...                ...
# 625                  Chelsea     Wolves        W            Chelsea
# 626        Nottingham Forest     Wolves        L  Nottingham Forest
# 627           Crystal Palace     Wolves        W     Crystal Palace
# 628           Leicester City     Wolves        W     Leicester City
# 629                Brentford     Wolves        D          Brentford
#
# [630 rows x 13 columns]
